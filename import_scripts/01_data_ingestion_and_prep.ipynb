# %%
# We will need this later to chunk books
# %pip install --upgrade semantic-kernel
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 8, Finished, Available)
# Collecting semantic-kernel
#   Downloading semantic_kernel-0.5.1.dev0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.5/244.5 kB 17.1 MB/s eta 0:00:00
# Collecting aiofiles<24.0.0,>=23.1.0 (from semantic-kernel)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-kernel) (3.8.6)
# Collecting motor<4.0.0,>=3.3.1 (from semantic-kernel)
#   Downloading motor-3.3.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.24.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-kernel) (1.24.3)
# Collecting openai>=1.0 (from semantic-kernel)
#   Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 88.3 MB/s eta 0:00:00
# Collecting openapi_core<0.19.0,>=0.18.0 (from semantic-kernel)
#   Downloading openapi_core-0.18.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 kB 40.5 MB/s eta 0:00:00
# Collecting prance<24.0.0.0,>=23.6.21.0 (from semantic-kernel)
#   Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Collecting pydantic>2 (from semantic-kernel)
#   Downloading pydantic-2.6.3-py3-none-any.whl (395 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.2/395.2 kB 79.5 MB/s eta 0:00:00
# Collecting python-dotenv==1.0.0 (from semantic-kernel)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: regex<2024.0.0,>=2023.6.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-kernel) (2023.8.8)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from aiohttp<4.0,>=3.8->semantic-kernel) (1.3.1)
# Collecting pymongo<5,>=4.5 (from motor<4.0.0,>=3.3.1->semantic-kernel)
#   Downloading pymongo-4.6.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.2/677.2 kB 98.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai>=1.0->semantic-kernel) (3.7.1)
# Collecting distro<2,>=1.7.0 (from openai>=1.0->semantic-kernel)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.0->semantic-kernel)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 38.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai>=1.0->semantic-kernel) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openai>=1.0->semantic-kernel) (4.66.1)
# Collecting typing-extensions<5,>=4.7 (from openai>=1.0->semantic-kernel)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting asgiref<4.0.0,>=3.6.0 (from openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: isodate in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (4.19.1)
# Collecting jsonschema-spec<0.3.0,>=0.2.3 (from openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading jsonschema_spec-0.2.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: more-itertools in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (10.1.0)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading openapi_schema_validator-0.6.2-py3-none-any.whl (8.8 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Collecting parse (from openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: werkzeug in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openapi_core<0.19.0,>=0.18.0->semantic-kernel) (3.0.1)
# Collecting chardet>=3.0 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel)
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 86.8 MB/s eta 0:00:00
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (0.17.32)
# Requirement already satisfied: requests>=2.25 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (2.31.0)
# Requirement already satisfied: six~=1.15 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (23.2)
# Collecting annotated-types>=0.4.0 (from pydantic>2->semantic-kernel)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic>2->semantic-kernel)
#   Downloading pydantic_core-2.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 131.0 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel) (3.4)
# Requirement already satisfied: exceptiongroup in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel) (1.1.3)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel) (2023.7.22)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: h11<0.15,>=0.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.10.6)
# Requirement already satisfied: PyYAML>=5.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jsonschema-spec<0.3.0,>=0.2.3->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (6.0.1)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-spec<0.3.0,>=0.2.3->openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading pathable-0.4.3-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: rfc3339-validator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (0.1.4)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading jsonschema_path-0.3.2-py3-none-any.whl (14 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.19.0,>=0.18.0->semantic-kernel)
#   Downloading lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 kB 29.4 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5,>=4.5->motor<4.0.0,>=3.3.1->semantic-kernel)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 92.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (1.26.17)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel) (0.2.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from werkzeug->openapi_core<0.19.0,>=0.18.0->semantic-kernel) (2.1.3)
# Installing collected packages: parse, typing-extensions, python-dotenv, pathable, lazy-object-proxy, httpcore, dnspython, distro, chardet, annotated-types, aiofiles, pymongo, pydantic-core, prance, jsonschema-spec, jsonschema-path, httpx, asgiref, pydantic, motor, openapi-schema-validator, openai, openapi-spec-validator, openapi_core, semantic-kernel
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Not uninstalling typing-extensions at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c977b6b3-ef8b-4a50-a820-d9ae445097df
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.9
#     Not uninstalling pydantic at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c977b6b3-ef8b-4a50-a820-d9ae445097df
#     Can't uninstall 'pydantic'. No files were found to uninstall.
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.8
#     Not uninstalling openai at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-c977b6b3-ef8b-4a50-a820-d9ae445097df
#     Can't uninstall 'openai'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 2.0.0 requires sentencepiece, which is not installed.
# sentence-transformers 2.0.0 requires torchvision, which is not installed.
# dash 2.14.0 requires Flask<2.3.0,>=1.0.4, but you have flask 3.0.0 which is incompatible.
# dash 2.14.0 requires Werkzeug<2.3.0, but you have werkzeug 3.0.1 which is incompatible.
# tensorflow 2.12.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.10.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 asgiref-3.7.2 chardet-5.2.0 distro-1.9.0 dnspython-2.6.1 httpcore-1.0.4 httpx-0.27.0 jsonschema-path-0.3.2 jsonschema-spec-0.2.4 lazy-object-proxy-1.10.0 motor-3.3.2 openai-1.13.3 openapi-schema-validator-0.6.2 openapi-spec-validator-0.7.1 openapi_core-0.18.2 parse-1.20.1 pathable-0.4.3 prance-23.6.21.0 pydantic-2.6.3 pydantic-core-2.16.3 pymongo-4.6.2 python-dotenv-1.0.0 semantic-kernel-0.5.1.dev0 typing-extensions-4.10.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# # Create Lakehouse Folders

# %%
import os

root_dir = '/lakehouse/default/Files'
main_folders = ['keys','book_texts','book_enriched']

for folder in main_folders:
    os.makedirs(os.path.join(root_dir, folder), exist_ok=True)

print("Directory structure created successfully!")
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 10, Finished, Available)
# Directory structure created successfully!

# %% [markdown]
# # Ingest Data From Source
#
# While I recommend using the provided defaults, two parameters are available to modify:
#
# - **books_to_ingest** - amount of books that you would like to store and analyze. Increasing this will exponentially increase TSNE analysis later
# - **max_byte_size** - max allowed size of each book in bytes

# %%
import requests

books_ingested = 0
book_content = []

books_to_ingest = 30  # modify based on your needs
max_byte_size = 100000  # modify based on your needs

for book_id in range(1, 1000):
    url = f'https://www.gutenberg.org/cache/epub/{book_id}/pg{book_id}.txt'

    # Check file size
    response = requests.head(url)
    content_length = int(response.headers.get('Content-Length', 0))

    if content_length <= max_byte_size:
        full_response = requests.get(url)

        if full_response.status_code == 200:
            book_text = full_response.text

            # Save file to default lakehouse
            with open(f'/lakehouse/default/Files/book_texts/{book_id}.txt', 'w') as file:
                file.write(book_text)

            book_content.append((book_id, book_text))
            books_ingested += 1
            print(f'Success book {book_id}: {books_ingested}/{books_to_ingest}')

            if books_ingested >= books_to_ingest:
                break
        else:
            print(f"Error fetching book {book_id}: Status code {full_response.status_code}")
    else:
        print(f"Skipping book {book_id}: Content size exceeds limit")
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 11, Finished, Available)
# Skipping book 1: Content size exceeds limit
# Success book 2: 1/30
# Success book 3: 2/30
# Success book 4: 3/30
# Success book 5: 4/30
# Success book 6: 5/30
# Success book 7: 6/30
# Success book 8: 7/30
# Success book 9: 8/30
# Skipping book 10: Content size exceeds limit
# Skipping book 11: Content size exceeds limit
# Skipping book 12: Content size exceeds limit
# Success book 13: 9/30
# Skipping book 14: Content size exceeds limit
# Skipping book 15: Content size exceeds limit
# Skipping book 16: Content size exceeds limit
# Skipping book 17: Content size exceeds limit
# Skipping book 18: Content size exceeds limit
# Skipping book 19: Content size exceeds limit
# Skipping book 20: Content size exceeds limit
# Skipping book 21: Content size exceeds limit
# Skipping book 22: Content size exceeds limit
# Skipping book 23: Content size exceeds limit
# Skipping book 24: Content size exceeds limit
# Skipping book 25: Content size exceeds limit
# Skipping book 26: Content size exceeds limit
# Skipping book 27: Content size exceeds limit
# Skipping book 28: Content size exceeds limit
# Skipping book 29: Content size exceeds limit
# Skipping book 30: Content size exceeds limit
# Skipping book 31: Content size exceeds limit
# Skipping book 32: Content size exceeds limit
# Skipping book 33: Content size exceeds limit
# Skipping book 34: Content size exceeds limit
# Skipping book 35: Content size exceeds limit
# Skipping book 36: Content size exceeds limit
# Skipping book 37: Content size exceeds limit
# Skipping book 38: Content size exceeds limit
# Success book 39: 10/30
# Skipping book 40: Content size exceeds limit
# Success book 41: 11/30
# Skipping book 42: Content size exceeds limit
# Skipping book 43: Content size exceeds limit
# Skipping book 44: Content size exceeds limit
# Skipping book 45: Content size exceeds limit
# Skipping book 46: Content size exceeds limit
# Skipping book 47: Content size exceeds limit
# Skipping book 48: Content size exceeds limit
# Success book 49: 12/30
# Skipping book 50: Content size exceeds limit
# Skipping book 51: Content size exceeds limit
# Error fetching book 52: Status code 404
# Skipping book 53: Content size exceeds limit
# Skipping book 54: Content size exceeds limit
# Skipping book 55: Content size exceeds limit
# Skipping book 218: Content size exceeds limit
# Skipping book 219: Content size exceeds limit
# Skipping book 220: Content size exceeds limit
# Skipping book 221: Content size exceeds limit
# Skipping book 222: Content size exceeds limit
# Skipping book 223: Content size exceeds limit
# Skipping book 224: Content size exceeds limit
# Skipping book 225: Content size exceeds limit
# Skipping book 226: Content size exceeds limit
# Skipping book 227: Content size exceeds limit
# Skipping book 228: Content size exceeds limit
# Success book 229: 27/30
# Success book 230: 28/30
# Skipping book 231: Content size exceeds limit
# Skipping book 232: Content size exceeds limit
# Skipping book 233: Content size exceeds limit
# Skipping book 234: Content size exceeds limit
# Success book 235: 29/30
# Skipping book 236: Content size exceeds limit
# Success book 237: 30/30

# %% [markdown]
# # Text Chunking with Semantic Kernel

# %%
from semantic_kernel.text import text_chunker
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 12, Finished, Available)

# %%
import json

def chunk_and_save_text(x):
    book_id,book_text = x

    start_index = book_text.index('*** START')
    end_index = book_text.index('*** END')

    # Get the header, footer, and main text of Project Gutenberg eBook
    header_text = book_text[0:start_index]
    main_text = book_text[start_index:end_index]

    # Use Semantic Kernel to chunk main text by tokens
    chunks = text_chunker.split_plaintext_lines(text=main_text, max_token_per_line=2000)
    print(f'Chunked book {book_id} into {len(chunks)} pieces')

    chunk_list = [{'chunk_id': i, 'content': chunk} for i, chunk in enumerate(chunks)]

    json_object = {
        'book_id': book_id,
        'header_text': header_text,
        'chunks': chunk_list
    }

    with open(f'/lakehouse/default/Files/book_enriched/{book_id}.json','w') as f:
        json.dump(json_object, f, indent=4)
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 13, Finished, Available)

# %%
for book in book_content:
    chunk_and_save_text(book)
# Out:
# StatementMeta(, 2d270a25-df40-44a5-8fa8-5b0bd2f735f5, 14, Finished, Available)
# Chunked book 2 into 1 pieces
# Chunked book 3 into 1 pieces
# Chunked book 4 into 1 pieces
# Chunked book 5 into 4 pieces
# Chunked book 6 into 1 pieces
# Chunked book 7 into 1 pieces
# Chunked book 8 into 1 pieces
# Chunked book 9 into 4 pieces
# Chunked book 13 into 8 pieces
# Chunked book 39 into 8 pieces
# Chunked book 41 into 16 pieces
# Chunked book 49 into 8 pieces
# Chunked book 56 into 4 pieces
# Chunked book 57 into 4 pieces
# Chunked book 61 into 16 pieces
# Chunked book 71 into 8 pieces
# Chunked book 99 into 8 pieces
# Chunked book 104 into 2 pieces
# Chunked book 109 into 8 pieces
# Chunked book 117 into 1 pieces
# Chunked book 136 into 8 pieces
# Chunked book 151 into 4 pieces
# Chunked book 156 into 1 pieces
# Chunked book 181 into 8 pieces
# Chunked book 207 into 16 pieces
# Chunked book 216 into 8 pieces
# Chunked book 229 into 8 pieces
# Chunked book 230 into 8 pieces
# Chunked book 235 into 2 pieces
# Chunked book 237 into 6 pieces
